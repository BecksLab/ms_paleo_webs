# %% [markdown]
# # SuppMat 1: Comparing models using contemporary food webs
#
# Tanya Strydom [![](data:image/png;base64,...)](https://orcid.org/0000-0001-6067-1349)
# December 16, 2024
#
# As a test I’m going to use an empirical dataset to compare the different models.
#
# Playing around with using the Pomeranz et al. ([2018](#ref-pomeranz2018)) dataset because they have most of the traits we need for all models but the PFIM…
#
# <figure>
# <img src="attachment:figures/summary_contemporary.png" alt="Something about X marking the spot… anyway that’s the real value and coloured points indicate the predicted value." />
# <figcaption aria-hidden="true">Something about X marking the spot… anyway that’s the real value and coloured points indicate the predicted value.</figcaption>
# </figure>
#
# <figure>
# <img src="attachment:figures/zscore_contemporary.png" alt="Z-score. Its a bit janky because its 1:1 (one prediction for each site) but it gives one an idea?" />
# <figcaption aria-hidden="true">Z-score. Its a bit janky because its 1:1 (one prediction for each site) but it gives one an idea?</figcaption>
# </figure>
#
# # References
#
# Pomeranz, Justin PF, Ross M. Thompson, Timothée Poisot, and Jon S. Harding. 2018. “Inferring Predator-Prey Interactions in Food Webs.” *Methods in Ecology and Evolution* 0 (ja). <https://doi.org/10.1111/2041-210X.13125>.
